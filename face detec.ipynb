# %%
import cv2

# %%
img2=cv2.imread("girl.jpg",1)

# %%
import matplotlib.pyplot as plt

# %%
from deepface import DeepFace

# %%
plt.imshow(img2)

# %%
plt.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB))

# %%
#predictiosDeepFace.a

# %%
#from deepface import DeepFace

# %%
 DeepFace.analyze(img2,enforce_detection=False)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:10<00:00,  2.62s/it]
# {'emotion': {'angry': 0.005997404865494764,
#   'disgust': 9.302542956893749e-07,
#   'fear': 3.221791249131113,
#   'happy': 91.00858461959179,
#   'sad': 0.06716915741344183,
#   'surprise': 0.617569758602352,
#   'neutral': 5.07888854490382},
#  'dominant_emotion': 'happy',
#  'region': {'x': 159, 'y': 214, 'w': 655, 'h': 655},
#  'age': 29,
#  'gender': 'Woman',
#  'race': {'asian': 21.657047767287228,
#   'indian': 15.54285771165582,
#   'black': 40.84165881176696,
#   'white': 2.237130968228694,
#   'middle eastern': 1.810380473480281,
#   'latino hispanic': 17.910931159368893},
#  'dominant_race': 'black'}

# %%
prediction=DeepFace.analyze(img2)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.52it/s]

# %%
prediction
# Out:
# {'emotion': {'angry': 0.005997404865494764,
#   'disgust': 9.302542956893749e-07,
#   'fear': 3.221791249131113,
#   'happy': 91.00858461959179,
#   'sad': 0.06716915741344183,
#   'surprise': 0.617569758602352,
#   'neutral': 5.07888854490382},
#  'dominant_emotion': 'happy',
#  'region': {'x': 159, 'y': 214, 'w': 655, 'h': 655},
#  'age': 29,
#  'gender': 'Woman',
#  'race': {'asian': 21.657047767287228,
#   'indian': 15.54285771165582,
#   'black': 40.84165881176696,
#   'white': 2.237130968228694,
#   'middle eastern': 1.810380473480281,
#   'latino hispanic': 17.910931159368893},
#  'dominant_race': 'black'}

# %%
type(prediction)
# Out:
# dict

# %%
prediction['dominant_emotion']
# Out:
# 'happy'

# %%
#from deepface import DeepFace

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h)in faces:
    cv2.rectangle(img2,(x,y),(x+w,y+h),(0,255,0),2)

# %%
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img2,
               prediction['dominant_emotion'],
               (50,50),
                font,1,
               (0,255,0),
               2,
               cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB))

# %%
#import numpy as np

# %%
obj=cv2.VideoCapture(0)

# %%
while True: 
    ret,frame=obj.read()
    result=DeepFace.analyze(frame,actions=['emotion'])
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    faces=faceCascade.detectMultiScale(gray,1.1,4)
    for(x,y,w,h)in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
    font=cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame,
                result['dominant_emotion'],
                (50,50), 
                font,3,
                (0,0,255),
                2,
                cv2.LINE_4);
    cv2.imshow('original video',frame)
    if cv2.waitKey(2) & 0xFF==ord('q'):
           break
obj.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 while True:
#       2     ret,frame=obj.read()
# ----> 3     result=DeepFace.analyze(frame,actions=['emotion'])
#       4     gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
#       5     faces=faceCascade.detectMultiScale(gray,1.1,4)
#
# File E:\anaconda3\envs\tesflow\lib\site-packages\deepface\DeepFace.py:391, in analyze(img_path, actions, models, enforce_detection, detector_backend, prog_bar)
#     389 if action == 'emotion':
#     390 	emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']
# --> 391 	img, region = functions.preprocess_face(img = img_path, target_size = (48, 48), grayscale = True, enforce_detection = enforce_detection, detector_backend = detector_backend, return_region = True)
# ...

# %%
DeepFace.analyze(frame,enforce_detection=False)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.66it/s]
# {'emotion': {'angry': 0.0043856415572167,
#   'disgust': 2.331119909226099e-19,
#   'fear': 95.42687508028001,
#   'happy': 8.84111528404332e-13,
#   'sad': 4.568736900015884,
#   'surprise': 1.7977390358376546e-19,
#   'neutral': 2.2604986451172198e-11},
#  'dominant_emotion': 'fear',
#  'region': {'x': 0, 'y': 0, 'w': 480, 'h': 640},
#  'age': 33,
#  'gender': 'Man',
#  'race': {'asian': 0.3939687043558779,
#   'indian': 0.057711199571859814,
#   'black': 0.004756436384666644,
#   'white': 92.17507792562711,
#   'middle eastern': 3.6855070254508866,
#   'latino hispanic': 3.6829846312394516},
#  'dominant_race': 'white'}
